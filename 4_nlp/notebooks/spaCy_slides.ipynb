# %% [markdown]
# # Text analysis with spaCy

# %% [markdown]
# ## What is spaCy?
# https://spacy.io
#
# spaCy is a library for advanced Natural Language Processing that utilizes convolution network models for English, German, Spanish, Portuguese, French, Italian, Dutch and multi-language NER, as well as tokenization for various other languages.

# %% [markdown]
# spaCy is designed for large scale text extraction, using Cython to provide increased processing speed. spaCy also supports deep learning workflows that allow connecting statistical models trained by popular machine learning libraries like TensorFlow, Keras, Scikit-learn or PyTorch.

# %% [markdown]
# ## Install required packages and models

# %%
import spacy
from spacy import displacy # visualization tools for spaCy

# %% [markdown]
# ## Model: 'en_core_web_lg'
#
# English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl. Assigns word vectors, context-specific token vectors, POS tags, syntactic dependency parse and named entities.
#
# 685k keys, 685k unique vectors (300 dimensions)

# %%
#!python -m spacy download en_core_web_lg
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Tokenization
#
# spaCy automatically tokenizes text and provides several context relevant properties for each token.
#
# Let's look at the following sentence:

# %% [markdown]
# **In downtown Evanston, Rhonda Smith bought 1 iPhone at 8 a.m. on October 5th because they were 30% off at BestBuy.**

# %%
# process document with spaCy nlp model
doc = nlp(u'In downtown Evanston, Rhonda Smith bought 1 iPhone at 8 a.m. on October 5th because they were 30% off at BestBuy.')

# get tokenized representation of sentence
tokenized = [token for token in doc]
print(tokenized)
# Out:
# [In, downtown, Evanston, ,, Rhonda, Smith, bought, 1, iPhone, at, 8, a.m., on, October, 5th, because, they, were, 30, %, off, at, BestBuy, .]

# %% [markdown]
# ## Named entity recognition

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">In downtown
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Evanston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rhonda Smith
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     8 a.m.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     October 5th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  because they were
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     30%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  off at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BestBuy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>

# %% [markdown]
# ## Named entities can be used for disambiguation

# %%
doc = nlp(u"Tim Cook, CEO of Apple, has many apple trees on his property.")
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tim Cook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , CEO of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , has many apple trees on his property.</div>

# %% [markdown]
# ## Token properties

# %%
# print properties of each token in sentence

import pandas as pd
from IPython.display import display, HTML

df = pd.DataFrame(columns='TEXT LEMMA POS TAG DEP SHAPE ALPHA ENT'.split())

for token in doc:
    tokendict = {'TEXT':token.text,
                 'LEMMA':token.lemma_,
                 'POS':token.pos_,
                 'TAG':token.tag_,
                 'DEP':token.dep_,
                 'SHAPE':token.shape_,
                 'ALPHA':token.is_alpha,
                 'ENT':token.ent_type_}
    df = df.append(tokendict, ignore_index=True)

display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>TEXT</th>
#       <th>LEMMA</th>
#       <th>POS</th>
#       <th>TAG</th>
#       <th>DEP</th>
#       <th>SHAPE</th>
#       <th>ALPHA</th>
#       <th>ENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Tim</td>
#       <td>tim</td>
#       <td>PROPN</td>
#       <td>NNP</td>
#       <td>compound</td>
#       <td>Xxx</td>
#       <td>True</td>
#       <td>PERSON</td>
#     </tr>
#     <tr>
#       <td>Cook</td>
#       <td>cook</td>
#       <td>PROPN</td>
#       <td>NNP</td>
#       <td>nsubj</td>
#       <td>Xxxx</td>
#       <td>True</td>
#       <td>PERSON</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>,</td>
#       <td>PUNCT</td>
#       <td>,</td>
#       <td>punct</td>
#       <td>,</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>CEO</td>
#       <td>ceo</td>
#       <td>PROPN</td>
#       <td>NNP</td>
#       <td>appos</td>
#       <td>XXX</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>of</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>prep</td>
#       <td>xx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Apple</td>
#       <td>apple</td>
#       <td>PROPN</td>
#       <td>NNP</td>
#       <td>pobj</td>
#       <td>Xxxxx</td>
#       <td>True</td>
#       <td>ORG</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>,</td>
#       <td>PUNCT</td>
#       <td>,</td>
#       <td>punct</td>
#       <td>,</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>has</td>
#       <td>have</td>
#       <td>VERB</td>
#       <td>VBZ</td>
#       <td>ROOT</td>
#       <td>xxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>many</td>
#       <td>many</td>
#       <td>ADJ</td>
#       <td>JJ</td>
#       <td>amod</td>
#       <td>xxxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>apple</td>
#       <td>apple</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>compound</td>
#       <td>xxxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>trees</td>
#       <td>tree</td>
#       <td>NOUN</td>
#       <td>NNS</td>
#       <td>dobj</td>
#       <td>xxxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>on</td>
#       <td>on</td>
#       <td>ADP</td>
#       <td>IN</td>
#       <td>prep</td>
#       <td>xx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>his</td>
#       <td>-PRON-</td>
#       <td>ADJ</td>
#       <td>PRP$</td>
#       <td>poss</td>
#       <td>xxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>property</td>
#       <td>property</td>
#       <td>NOUN</td>
#       <td>NN</td>
#       <td>pobj</td>
#       <td>xxxx</td>
#       <td>True</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>.</td>
#       <td>PUNCT</td>
#       <td>.</td>
#       <td>punct</td>
#       <td>.</td>
#       <td>False</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Syntactic dependency relationships
#
# Syntactic dependencies are the grammatical relationships between words. spaCy can be used to extract this dependency information from sentences in a text.

# %%
# visualization of syntactic dependency 
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2150" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Cook,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Apple,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">trees</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">property.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 925.0,2.0 925.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M945,352.0 C945,89.5 1445.0,89.5 1445.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,354.0 L1453.0,342.0 1437.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M945,352.0 C945,2.0 1625.0,2.0 1625.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1625.0,354.0 L1633.0,342.0 1617.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-9" stroke-width="2px" d="M1820,352.0 C1820,264.5 1960.0,264.5 1960.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %% [markdown]
# # Syntactic dependency relationships in practice:
# ### Currency values in press releases and the nouns they refer to

# %%
# define functions

class stop_loop(Exception): pass

def qualifier_value(money_txt):
    money_doc = nlp(str(money_txt))
    pos_list = [token.pos_ for token in money_doc]
    money_list = [token.text for token in money_doc]
    money_start = min(loc for loc, pos in enumerate(pos_list) if (pos == 'SYM' or pos == 'NUM'))
    qualifier = ' '.join(money_list[:money_start])
    value = ' '.join(money_list[money_start:])
    return qualifier, value
    

def extract_currency_relations(doc):
    # merge entities and noun chunks into one token
    spans = list(doc.ents) + list(doc.noun_chunks)
    for span in spans:
        span.merge()

    relations = []
    for money in filter(lambda w: w.ent_type_ == 'MONEY', doc):
        try:
            # syntactic relationship 1
            advcl = [w for w in money.head.children if w.dep_ == 'advcl']
            if advcl:
                for child in advcl[0].children:
                    if child.dep_ == 'dobj':
                        parse_type = 1
                        qual, val = qualifier_value(money.text)
                        relations.append((qual, val, child, parse_type))
                        raise stop_loop()
                        
            # syntactic relationship 2
            cprep = [w for w in money.children if w.dep_ == 'prep']
            if cprep:
                for child in cprep[0].children:
                    if child.dep_ == 'pobj':
                        parse_type = 2
                        qual, val = qualifier_value(money.text)
                        relations.append((qual, val, child, parse_type))
                        raise stop_loop()
            
            # syntactic relationship 3
            hprep = [w for w in money.head.children if w.dep_ == 'prep']
            if hprep:
                for child in hprep[0].children:
                    if child.dep_ == 'pobj':
                        parse_type = 3
                        qual, val = qualifier_value(money.text)
                        relations.append((qual, val, child, parse_type))
                        raise stop_loop()
                        
            # syntactic relationship 4
            if money.dep_ in ('attr', 'dobj'):
                subject = [w for w in money.head.lefts if w.dep_ == 'nsubj']
                if subject:
                    parse_type = 4
                    subject = subject[0]
                    qual, val = qualifier_value(money.text)
                    relations.append((qual, val, subject, parse_type))
                    raise stop_loop()
                    
            # syntactic relationship 5
            elif money.dep_ == 'pobj' and money.head.dep_ == 'prep':
                parse_type = 5
                qual, val = qualifier_value(money.text)
                relations.append((qual, val, money.head.head, parse_type))
                raise stop_loop()
                
        except stop_loop:
            pass
                 
    return relations

# %%
from bs4 import BeautifulSoup
import zipfile

'''
iterate over zip file of press releases and
extract currency values, the assets they refer to,
and qualifying adjectives
'''

df = pd.DataFrame(columns='FILENAME TIMESTAMP TITLE QUALIFIER VALUE ASSET'.split())
data_dir = "../data/press_releases/"

with zipfile.ZipFile(data_dir+"AMZN.zip", "r") as f:
    for filename in f.namelist():
        if not filename.startswith("AMZN") or filename == "AMZN/" or "MACOS" in filename:
            continue
        print(filename)
        html = f.read(filename)
        soup = BeautifulSoup(html)
        body = soup.findAll("div", {"class": "caas-body"})
        heading = soup.findAll("h1", {"data-test-locator": "headline"})
        date_time = soup.findAll("time")
        try:
            timestamp = date_time[0]['datetime']
        except IndexError:
            timestamp = ''
        try:
            title = heading[0]
        except IndexError:
            continue
        try:
            text = body[0].text
        except IndexError:
            continue
        doc = nlp(str(text))
        try:
            relations = extract_currency_relations(doc)
        except ValueError:
            continue
        for r0, r1, r2, r3 in relations:
            relation_dict = {'FILENAME':filename, 'TIMESTAMP':timestamp, 'TITLE':title, 'QUALIFIER':r0, 'VALUE':r1, 'ASSET':r2.text}
            df = df.append(relation_dict, ignore_index=True)
# Out:
# AMZN/AMZN103.html
# AMZN/AMZN19.html
# AMZN/AMZN154.html
# AMZN/AMZN6.html
# AMZN/AMZN142.html
# AMZN/AMZN58.html
# AMZN/AMZN115.html
# AMZN/AMZN74.html
# AMZN/AMZN23.html
# AMZN/AMZN139.html
# AMZN/AMZN35.html
# AMZN/AMZN62.html
# AMZN/AMZN15.html
# AMZN/AMZN158.html
# AMZN/AMZN42.html
# AMZN/AMZN54.html
# AMZN/AMZN119.html
# AMZN/AMZN78.html
# AMZN/AMZN97.html
# AMZN/AMZN162.html
# AMZN/AMZN135.html
# AMZN/AMZN39.html
# AMZN/AMZN123.html
# AMZN/AMZN81.html
# AMZN/AMZN80.html
# AMZN/AMZN38.html
# AMZN/AMZN122.html
# AMZN/AMZN134.html
# AMZN/AMZN79.html
# AMZN/AMZN96.html
# AMZN/AMZN163.html
# AMZN/AMZN118.html
# AMZN/AMZN55.html
# AMZN/AMZN159.html
# AMZN/AMZN43.html
# AMZN/AMZN14.html
# AMZN/AMZN63.html
# AMZN/AMZN34.html
# AMZN/AMZN22.html
# AMZN/AMZN138.html
# AMZN/AMZN75.html
# AMZN/AMZN114.html
# AMZN/AMZN143.html
# AMZN/AMZN59.html
# AMZN/AMZN7.html
# AMZN/AMZN155.html
# AMZN/AMZN102.html
# AMZN/AMZN18.html
# AMZN/AMZN109.html
# AMZN/AMZN13.html
# AMZN/AMZN44.html
# AMZN/AMZN148.html
# AMZN/AMZN52.html
# AMZN/AMZN164.html
# AMZN/AMZN91.html
# AMZN/AMZN29.html
# AMZN/AMZN133.html
# AMZN/AMZN125.html
# AMZN/AMZN68.html
# AMZN/AMZN87.html
# AMZN/AMZN105.html
# AMZN/AMZN152.html
# AMZN/AMZN48.html
# AMZN/AMZN144.html
# AMZN/AMZN113.html
# AMZN/AMZN72.html
# AMZN/AMZN168.html
# AMZN/AMZN25.html
# AMZN/AMZN33.html
# AMZN/AMZN129.html
# AMZN/AMZN64.html
# AMZN/AMZN65.html
# AMZN/AMZN32.html
# AMZN/AMZN128.html
# AMZN/AMZN24.html
# AMZN/AMZN73.html
# AMZN/AMZN169.html
# AMZN/AMZN112.html
# AMZN/AMZN145.html
# AMZN/AMZN1.html
# AMZN/AMZN153.html
# AMZN/AMZN49.html
# AMZN/AMZN104.html
# AMZN/AMZN69.html
# AMZN/AMZN86.html
# AMZN/AMZN124.html
# AMZN/AMZN28.html
# AMZN/AMZN132.html
# AMZN/AMZN165.html
# AMZN/AMZN90.html
# AMZN/AMZN149.html
# AMZN/AMZN53.html
# AMZN/AMZN45.html
# AMZN/AMZN108.html
# AMZN/AMZN12.html
# AMZN/AMZN170.html
# AMZN/AMZN85.html
# AMZN/AMZN127.html
# AMZN/AMZN131.html
# AMZN/AMZN93.html
# AMZN/AMZN166.html
# AMZN/AMZN50.html
# AMZN/AMZN46.html
# AMZN/AMZN11.html
# AMZN/AMZN89.html
# AMZN/AMZN66.html
# AMZN/AMZN31.html
# AMZN/AMZN27.html
# AMZN/AMZN70.html
# AMZN/AMZN111.html
# AMZN/AMZN146.html
# AMZN/AMZN2.html
# AMZN/AMZN150.html
# AMZN/AMZN107.html
# AMZN/AMZN106.html
# AMZN/AMZN151.html
# AMZN/AMZN3.html
# AMZN/AMZN147.html
# AMZN/AMZN110.html
# AMZN/AMZN71.html
# AMZN/AMZN26.html
# AMZN/AMZN30.html
# AMZN/AMZN88.html
# AMZN/AMZN67.html
# AMZN/AMZN10.html
# AMZN/AMZN47.html
# AMZN/AMZN51.html
# AMZN/AMZN92.html
# AMZN/AMZN167.html
# AMZN/AMZN130.html
# AMZN/AMZN126.html
# AMZN/AMZN84.html
# AMZN/AMZN60.html
# AMZN/AMZN37.html
# AMZN/AMZN21.html
# AMZN/AMZN99.html
# AMZN/AMZN76.html
# AMZN/AMZN117.html
# AMZN/AMZN140.html
# AMZN/AMZN4.html
# AMZN/AMZN156.html
# AMZN/AMZN101.html
# AMZN/AMZN83.html
# AMZN/AMZN121.html
# AMZN/AMZN137.html
# AMZN/AMZN160.html
# AMZN/AMZN95.html
# AMZN/AMZN56.html
# AMZN/AMZN40.html
# AMZN/AMZN8.html
# AMZN/AMZN17.html
# AMZN/AMZN16.html
# AMZN/AMZN9.html
# AMZN/AMZN41.html
# AMZN/AMZN57.html
# AMZN/AMZN161.html
# AMZN/AMZN94.html
# AMZN/AMZN136.html
# AMZN/AMZN120.html
# AMZN/AMZN82.html
# AMZN/AMZN100.html
# AMZN/AMZN157.html
# AMZN/AMZN5.html
# AMZN/AMZN141.html
# AMZN/AMZN116.html
# AMZN/AMZN98.html
# AMZN/AMZN77.html
# AMZN/AMZN20.html
# AMZN/AMZN36.html
# AMZN/AMZN61.html

# %%
# print dataframe
df = df.sort_values(by=['TIMESTAMP'])
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>FILENAME</th>
#       <th>TIMESTAMP</th>
#       <th>TITLE</th>
#       <th>QUALIFIER</th>
#       <th>VALUE</th>
#       <th>ASSET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td>a</td>
#       <td>$ 3 million donation</td>
#       <td>Amazon Canada</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td></td>
#       <td>$ 7.5 billion</td>
#       <td>Canada</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td></td>
#       <td>16</td>
#       <td>starting</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN168.html</td>
#       <td>2020-07-07T14:30:00.000Z</td>
#       <td>[Amazon Announces First Fulfillment Center and Second Delivery Station in Little Rock]</td>
#       <td></td>
#       <td>15</td>
#       <td>Amazon’s industry-leading minimum starting wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>$ 1 million</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>500,000</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>$ 15 billion</td>
#       <td>small and medium-sized businesses</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN163.html</td>
#       <td>2020-07-15T07:00:00.000Z</td>
#       <td>[AWS and HSBC Reach Long-Term Strategic Cloud Agreement]</td>
#       <td></td>
#       <td>US$ 2,918bn</td>
#       <td>assets</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>an additional</td>
#       <td>$ 9 billion</td>
#       <td>the Texas economy</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>more than</td>
#       <td>$ 10.5 billion</td>
#       <td>its local fulfillment center infrastructure</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td></td>
#       <td>15</td>
#       <td>Amazon’s minimum starting wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td></td>
#       <td>15</td>
#       <td>wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>over</td>
#       <td>$ 700 million</td>
#       <td>upskilling training</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN159.html</td>
#       <td>2020-07-16T19:55:00.000Z</td>
#       <td>[The Climate Pledge and the We Mean Business Coalition Partner on Comprehensive Effort to Drive Companies to Adopt More Ambitious Carbon Reduction Goals]</td>
#       <td>more than</td>
#       <td>$ 24.8 trillion</td>
#       <td>a total market capitalization</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>$ 1.28 billion</td>
#       <td>the launch</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>over</td>
#       <td>$ 160,000</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>approximately</td>
#       <td>$ 100,000.The number</td>
#       <td>American SMB sellers</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>$ 1 million</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>$ 500 million</td>
#       <td>2018.AWS Activate</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>$ 1 billion</td>
#       <td>AWS credits</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>100,000</td>
#       <td>royalties</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>$ 50,000</td>
#       <td>Thousands</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>$ 319 million</td>
#       <td>the Kindle Direct Publishing Select Global FundAmazon</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>$ 1 billion</td>
#       <td>AWS credits</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>over</td>
#       <td>$ 7 billion</td>
#       <td>American SMB sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>

# %%
# Convert monetary values to integer using regex substitution

import re

values = []
for text_value in df['VALUE']:
    if 'million' in text_value:
        money_expr = re.sub('million', '*1000000', text_value.strip())
    elif 'billion' in text_value:
        money_expr = re.sub('billion', '*1000000000', text_value.strip())
    elif 'trillion' in text_value:
        money_expr = re.sub('trillion', '*1000000000000', text_value.strip())
    money_expr = re.sub(r'\$', '', money_expr)
    try:
        money_value = eval(money_expr)
    except SyntaxError:
        money_value = str(text_value)
    values.append(money_value)
    
df_intvalue = df.assign(VALUE = values)

#pd. set_option('display. float_format', lambda x: '%. nf' % x)
display(HTML(df_intvalue.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>FILENAME</th>
#       <th>TIMESTAMP</th>
#       <th>TITLE</th>
#       <th>QUALIFIER</th>
#       <th>VALUE</th>
#       <th>ASSET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td>a</td>
#       <td>$ 3 million donation</td>
#       <td>Amazon Canada</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td></td>
#       <td>7.5e+09</td>
#       <td>Canada</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN169.html</td>
#       <td>2020-06-30T14:00:00.000Z</td>
#       <td>[Amazon Announces Plans to Build Second Fulfillment Centre in Ottawa]</td>
#       <td></td>
#       <td>7.5e+09</td>
#       <td>starting</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN168.html</td>
#       <td>2020-07-07T14:30:00.000Z</td>
#       <td>[Amazon Announces First Fulfillment Center and Second Delivery Station in Little Rock]</td>
#       <td></td>
#       <td>7.5e+09</td>
#       <td>Amazon’s industry-leading minimum starting wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>1000000</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>1000000</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN167.html</td>
#       <td>2020-07-09T10:01:00.000Z</td>
#       <td>[Amazon Reveals the Top 10 States with the Most Digital Entrepreneurs Per Capita and the Top 10 States with the Fastest Growing Digital Entrepreneurs: Iowa Tops Both Lists]</td>
#       <td></td>
#       <td>15000000000</td>
#       <td>small and medium-sized businesses</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN163.html</td>
#       <td>2020-07-15T07:00:00.000Z</td>
#       <td>[AWS and HSBC Reach Long-Term Strategic Cloud Agreement]</td>
#       <td></td>
#       <td>15000000000</td>
#       <td>assets</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>an additional</td>
#       <td>9000000000</td>
#       <td>the Texas economy</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>more than</td>
#       <td>1.05e+10</td>
#       <td>its local fulfillment center infrastructure</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td></td>
#       <td>1.05e+10</td>
#       <td>Amazon’s minimum starting wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td></td>
#       <td>1.05e+10</td>
#       <td>wage</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN161.html</td>
#       <td>2020-07-15T13:35:00.000Z</td>
#       <td>[Amazon Announces New Pflugerville Fulfillment Center]</td>
#       <td>over</td>
#       <td>700000000</td>
#       <td>upskilling training</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN159.html</td>
#       <td>2020-07-16T19:55:00.000Z</td>
#       <td>[The Climate Pledge and the We Mean Business Coalition Partner on Comprehensive Effort to Drive Companies to Adopt More Ambitious Carbon Reduction Goals]</td>
#       <td>more than</td>
#       <td>2.48e+13</td>
#       <td>a total market capitalization</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>1.28e+09</td>
#       <td>the launch</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>over</td>
#       <td>1.28e+09</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>approximately</td>
#       <td>1.28e+09</td>
#       <td>American SMB sellers</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>1000000</td>
#       <td>sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>500000000</td>
#       <td>2018.AWS Activate</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>1000000000</td>
#       <td>AWS credits</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td></td>
#       <td>1000000000</td>
#       <td>royalties</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>1000000000</td>
#       <td>Thousands</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>319000000</td>
#       <td>the Kindle Direct Publishing Select Global FundAmazon</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>more than</td>
#       <td>1000000000</td>
#       <td>AWS credits</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>
#       <td>[Amazon 2020 SMB Impact Report Highlights Success for Small and Medium-Sized Businesses Despite COVID-19; American Sellers Average $160,000 in Annual Sales]</td>
#       <td>over</td>
#       <td>7000000000</td>
#       <td>American SMB sales</td>
#     </tr>
#     <tr>
#       <td>AMZN/AMZN157.html</td>
#       <td>2020-07-21T07:01:00.000Z</td>

# %% [markdown]
# ## And much much more...
# https://spacy.io/usage/linguistic-features
